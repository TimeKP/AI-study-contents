# %% [markdown]
# <a href="https://colab.research.google.com/github/TimeKP/AI-study-contents/blob/main/loc%26iloc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

name_index = ['하나의 row 이름',
              'row 이름의 리스트',
              'row 이름의 리스트 슬라이싱',
              '하나의 column 이름',
              'column 이름의 리스트',
              'column 이름의 리스트 슬라이싱'
             ]
shape = ['df.loc["row4"]',
         'df.loc[["row4,"row5,"row3"]]',
         'df.loc["row2":"row5"]',
         'df.loc[:,"col1"]',
         'df.loc[:,["col4","col6","col3"]]',
         'df.loc[:,"col2":"col5"]'
        ]
shorten = ['',
           '',
           'df["row2":"row5"]',
           'df["col1"]',
           'df[["col4","col6","col3"]]',
           ''
          ]
dct1 = {
    '이름으로 인덱싱하기': name_index,
    '기본 형태': shape,
    '단축 형태': shorten
}

indexing = pd.DataFrame(dct1)
indexing
name_index1 = ['하나의 row 이름',
              'row 위치의 리스트',
              'row 위치의 리스트 슬라이싱',
              '하나의 column 위치',
              'column 위치의 리스트',
              'column 위치의 리스트 슬라이싱'
             ]
shape1 = ['df.iloc[8]',
         'df.iloc[[4,5,3]]',
         'df.iloc[2:5]',
         'df.iloc[:,3]',
         'df.iloc[:,[3,5,6]]',
         'df.loc[:,3:7]'
        ]
shorten1 = ['',
           '',
           'df[2:5]',
           '',
           '',
           ''
          ]
dct2 = {
    '위치로 인덱싱하기': name_index1,
    '기본 형태': shape1,
    '단축 형태': shorten1
}

indexing1 = pd.DataFrame(dct2)
indexing1
# Out:
#              위치로 인덱싱하기               기본 형태    단축 형태
# 0           하나의 row 이름          df.iloc[8]
# 1          row 위치의 리스트    df.iloc[[4,5,3]]
# 2     row 위치의 리스트 슬라이싱        df.iloc[2:5]  df[2:5]
# 3        하나의 column 위치        df.iloc[:,3]
# 4       column 위치의 리스트  df.iloc[:,[3,5,6]]
# 5  column 위치의 리스트 슬라이싱       df.loc[:,3:7]
